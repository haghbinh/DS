# %% [markdown]
# # SVD Decomposition

# %%
# pip install opencv-python
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
fname = "Einstein"
D = np.empty([1,440*589])
image_path='img/'+fname
image = cv2.imread(image_path, cv2.IMREAD_COLOR)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
x=np.array(gray)    
D[0,:] = x.flatten()
print(D[0,:])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [3], in <module>
#       3 image_path='img/'+fname
#       4 image = cv2.imread(image_path, cv2.IMREAD_COLOR)
# ----> 5 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       6 x=np.array(gray)
#       7 D[0,:] = x.flatten()
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
def read_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    print("image shape", image.shape)
    plt.imshow(image, cmap='gray')
    plt.show()
    return np.array(gray)

# %%
image_path='img/Einstein.png'
A=read_image(image_path)
# Out:
# image shape (589, 440, 3)

# %%
A.shape
# Out:
# (589, 440)

# %%
A
# Out:
# array([[ 63,  63,  61, ...,  24,  24,  24],
#        [ 62,  61,  63, ...,  24,  24,  24],
#        [ 62,  61,  61, ...,  24,  24,  24],
#        ...,
#        [ 25,  19,  19, ...,  73,  85,  85],
#        [ 22,  19,  22, ..., 113, 161,  99],
#        [ 28,  25,  31, ...,  74, 151, 151]], dtype=uint8)

# %%
U, D, V = np.linalg.svd(A, full_matrices=False)

# %%
U.shape
# Out:
# (589, 440)

# %%
# D = np.diag(D)
D.shape
# Out:
# (440,)

# %%
V.shape
# Out:
# (440, 440)

# %%
k=441
A25=np.round(np.dot(U[:,0:k]*D[0:k],V[0:k,:]))
img = np.uint8(A25)
img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')
plt.show()
